# %%
import os
import sys

# %%
os.environ["PYSPARK_PYTHON"]='/opt/anaconda/envs/bd9/bin/python'
os.environ["SPARK_HOME"]='/usr/hdp/current/spark2-client'
os.environ["PYSPARK_SUBMIT_ARGS"]='--num-executors 5 --executor-memory 4g --executor-cores 1 --driver-memory 2g pyspark-shell --master yarn --deploy-mode cluster'

spark_home = os.environ.get('SPARK_HOME', None)
if not spark_home:
    raise ValueError('SPARK_HOME environment variable is not set')

sys.path.insert(0, os.path.join(spark_home, 'python'))
sys.path.insert(0, os.path.join(spark_home, 'python/lib/py4j-0.10.7-src.zip'))
exec(open(os.path.join(spark_home, 'python/pyspark/shell.py')).read())
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 2.4.7
#       /_/
#
# Using Python version 3.6.5 (default, Apr 29 2018 16:14:56)
# SparkSession available as 'spark'.

# %%
from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import *
from pyspark import Row
import json

conf = SparkConf()
# conf.set("spark.enableHiveSupport", "True")

spark = (SparkSession
         .builder
         .config(conf=conf)
         .appName("lab_03_demenev")
         .getOrCreate())

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://spark-master-4.newprolab.com:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.7</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from time import time
import datetime
def print_worktime(t):
    h = int(t//3600)
    m = int(t // 60)
    s = (t % 60)
    print('Код отработал за {0} часов {1} минут {2} секунд'.format(h,m,s))

# %%
items = spark.read.csv('/labs/slaba03/laba03_items.csv', header=True, sep="\t")
test = spark.read.csv('/labs/slaba03/laba03_test.csv', header=True)
train = spark.read.csv('/labs/slaba03/laba03_train.csv', header=True)
programmes = spark.read.csv('/labs/slaba03/laba03_views_programmes.csv', header=True)

# %%
test.show(2)
# Out:
# +-------+-------+--------+
# |user_id|item_id|purchase|
# +-------+-------+--------+
# |   1654|  94814|    null|
# |   1654|  93629|    null|
# +-------+-------+--------+
# only showing top 2 rows

# %%
train.show(2)
# Out:
# +-------+-------+--------+
# |user_id|item_id|purchase|
# +-------+-------+--------+
# |   1654|  74107|       0|
# |   1654|  89249|       0|
# +-------+-------+--------+
# only showing top 2 rows

# %%
items.show(2, vertical=True, truncate=False)
# Out:
# -RECORD 0-------------------------------------------------------------------------------
#  item_id                     | 65667
#  channel_id                  | null
#  datetime_availability_start | 1970-01-01T00:00:00Z
#  datetime_availability_stop  | 2018-01-01T00:00:00Z
#  datetime_show_start         | null
#  datetime_show_stop          | null
#  content_type                | 1
#  title                       | на пробах только девушки (all girl auditions)
#  year                        | 2013.0
#  genres                      | Эротика
#  region_id                   | null
# -RECORD 1-------------------------------------------------------------------------------
#  item_id                     | 65669
#  channel_id                  | null
#  datetime_availability_start | 1970-01-01T00:00:00Z
#  datetime_availability_stop  | 2018-01-01T00:00:00Z
#  datetime_show_start         | null
#  datetime_show_stop          | null
#  content_type                | 1
#  title                       | скуби ду: эротическая пародия (scooby doo: a xxx parody)
#  year                        | 2011.0
#  genres                      | Эротика
#  region_id                   | null
# only showing top 2 rows

# %%
programmes.show(5)
# Out:
# +-------+-------+----------+----------+---------+
# |user_id|item_id|  ts_start|    ts_end|item_type|
# +-------+-------+----------+----------+---------+
# |      0|7101053|1491409931|1491411600|     live|
# |      0|7101054|1491412481|1491451571|     live|
# |      0|7101054|1491411640|1491412481|     live|
# |      0|6184414|1486191290|1486191640|     live|
# |    257|4436877|1490628499|1490630256|     live|
# +-------+-------+----------+----------+---------+
# only showing top 5 rows

# %%
import pyspark.sql.functions as f
from pyspark.sql.functions import collect_list
from pyspark.sql.types import LongType, StringType, StructType, StructField, ByteType, ArrayType
from pyspark.ml import Pipeline
from pyspark.ml.classification import RandomForestClassifier, LogisticRegression, GBTClassifier
from pyspark.ml.feature import Tokenizer, HashingTF, IDF, CountVectorizer

import re

# %%
@f.udf(ArrayType(StringType()))
def parsing_data(text: str):
    if text == None:
        return ['']
#     text = " ".join(regex.findall(str(text).lower())).split(" ")
    return [str(word).lower() for word in text]

# %%
train_genres = train.join(items.select('item_id', 'genres'), ['item_id'], how='left')
train_genres = train_genres.groupby('item_id').agg(f.collect_list('genres').alias('genre_list')).cache()
train_genres_user = train.join(items.select('item_id', 'genres'), ['item_id'], how='left')
train_genres_user = train_genres_user.groupby('user_id').agg(f.collect_list('genres').alias('genre_list_user')).cache()

# %%
train_genres_user.show(2, vertical=True, truncate=False)
# Out:
# -RECORD 0------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
#  user_id         | 921852                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
#  genre_list_user | [Комедии,Советское кино,Драмы,Русские, Мистические,Ужасы,Советское кино,Драмы, Драмы,Криминал, Русские мультфильмы,Русские,Советские,Для детей, Мистические,Детективы,Триллеры,Зарубежные, Ужасы,Комедия, Мультфильмы,Детские,Союзмультфильм,Наши, Триллеры,Драмы,Фантастика,Наши, Для всей семьи,Документальные,Зарубежные, Боевики,Криминал,Наши, Документальные, Комедии,Русские,Для всей семьи, Мультфильмы,Наши, Комедии,Мелодрамы,Зарубежные, Комедии,Русские,Музыкальные, Комедии,Драмы,Фантастика,Зарубежные, Развлекательные,Познавательные,Русские,Для всей семьи,Для детей, Драмы,Исторические,Криминал,Зарубежные,Биография, Ужасы,Фантастика,Зарубежные, Военные,Драмы,Исторические, Драмы,Зарубежные, Детективы,Мелодрамы,Криминал, Советские,Для детей, Детективы,Русские,Боевики, Ужасы,Триллеры,Зарубежные, Триллеры,Боевики,Зарубежные, Триллеры,Драмы,Зарубежные, Полнометражные,Для детей,Зарубежные, Документальные,Зарубежные, Драмы,Полнометражные,Аниме, Мелодрамы,Наши, Приключения,Фэнтези,Русские, Приключения,Детективы,Драмы,Фантастика,Мелодрамы,Боевики, Комедии,Драмы,Мелодрамы,Зарубежные, Детективы,Комедии,Русские, Русские мультфильмы,Про животных,Русские,Советские,Для детей, Детективы,Боевики,Для взрослых,Зарубежные, Приключения,Комедии,Полнометражные,Для всей семьи,Для детей,Зарубежные, Эротика, Драмы, Детективы,Советское кино,Триллеры, Приключения,Комедии,Фантастика, Комедии,Драмы,Мелодрамы, Эротика,Зарубежные, Драмы,Криминал,Наши, Комедии,Триллеры,Зарубежные, Русские мультфильмы,Русские,Советские,Для детей, Ужасы,Зарубежные, Приключения,Триллеры,Боевики,Зарубежные, Фэнтези,Русские,Для детей, Драмы,Мелодрамы,Зарубежные, Детективы,Триллеры,Драмы,Зарубежные, Комедии,Детективы,Наши, Ужасы,Триллеры,Драмы,Зарубежные, Драмы,Фантастика,Наши, Мелодрама,Драма, Детективы,Триллеры,Боевики,Зарубежные, Мультфильмы,Наши, Драмы,Русские,Документальные, Комедии,Мелодрамы,Наши, Детективы,Русские,Боевики, Исторический,Документальный,Драма, Про животных,Полнометражные,Сказки,Русские,Советские,Для детей, Мистические,Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Комедии,Мелодрамы,Зарубежные, Драмы,Криминал,Зарубежные, Комедии,Русские, Драмы,Зарубежные, Ужасы,Триллеры,Драмы, Фантастика,Боевики,Зарубежные, Познавательные,Русские,Для всей семьи,Для детей,Хочу всё знать,Спорт, Эротика, Драмы,Русские, Триллеры,Криминал,Зарубежные, Приключения,Комедии,Драмы,Мелодрамы,Зарубежные, Комедии,Наши, Эротика, Артхаус,Эротика,Триллеры,Драмы,Зарубежные, Эротика

# Out:
# -RECORD 0------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
#  item_id    | 100140                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
#  genre_list | [Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии, Комедии ...
# -RECORD 1------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
#  item_id    | 100263                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
#  genre_list | [Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драмы,Зарубежные, Ужасы,Детективы,Триллеры,Драм ...
# only showing top 2 rows

# %%
train_genres = train_genres.select('item_id', parsing_data('genre_list').alias('genres'))
train_genres_user = train_genres_user.select('user_id', parsing_data('genre_list_user').alias('genres_user'))

# %%
start = time()
cv_genre = CountVectorizer(inputCol="genres", outputCol="genre_features")
cv_genre_us = CountVectorizer(inputCol="genres_user", outputCol="genre_features_user")
model_genre = cv_genre.fit(train_genres)
model_genre_user = cv_genre_us.fit(train_genres_user)
result_genre_user = model_genre_user.transform(train_genres_user)
result_genre = model_genre.transform(train_genres)
print_worktime(time()-start)
# Out:
# Код отработал за 0 часов 0 минут 23.596380472183228 секунд

# %%
result_genre = result_genre.select('item_id', 'genre_features').distinct()
result_genre_user = result_genre_user.select('user_id', 'genre_features_user').distinct()

# %%
programmes = programmes.withColumn('length', f.col('ts_end') - f.col('ts_start'))
# programmes.show(5)

# %%
purch_am = train.groupby('item_id').agg(f.mean('purchase').alias('purch_prob'))
purch_am_user = train.groupby('user_id').agg(f.mean('purchase').alias('purch_prob_user'))

# %%
# watch metrics
user_views_df = programmes.groupby('user_id')\
                                .agg(F.sum('length').alias("sum_watch"),
                                     F.mean('length').alias("mean_watch"))

# %% [markdown]
# # Подход 1: предсказание через GBT classifier (долго и плохо)

# %%
train_with_features = train.join(purch_am, ['item_id'], how='left')
train_with_features = train_with_features.join(items.select(f.col('year').cast(DoubleType()).alias('year'), 'item_id'), ['item_id'], how='left')
train_with_features = train_with_features.join(purch_am_user, ['user_id'], how='left')
train_with_features = train_with_features.join(user_views_df, ['user_id'], how='left')
train_with_features = train_with_features.repartition(100)
train_with_features = train_with_features.join(result_genre_user, ['user_id'], how='left')
train_with_features = train_with_features.join(result_genre, ['item_id'], how='left').fillna(0).cache()

test_with_features = test.join(purch_am, ['item_id'], how='left')
test_with_features = test_with_features.join(items.select(f.col('year').cast(DoubleType()).alias('year'), 'item_id'), ['item_id'], how='left')
test_with_features = test_with_features.join(purch_am_user, ['user_id'], how='left')
test_with_features = test_with_features.join(user_views_df, ['user_id'], how='left')
test_with_features = test_with_features.repartition(100)
test_with_features = test_with_features.join(result_genre_user, ['user_id'], how='left')
test_with_features = test_with_features.join(result_genre, ['item_id'], how='left').fillna(0).cache()

# %%
start = time()
test_with_features.count()
print_worktime(time()-start)
# Out:
# Код отработал за 0 часов 2 минут 2.287085771560669 секунд

# %%
start = time()
train_with_features.count()
print_worktime(time()-start)
# Out:
# Код отработал за 0 часов 3 минут 34.253660440444946 секунд

# %%
train_with_features.columns
# Out:
# ['item_id',
#  'user_id',
#  'purchase',
#  'purch_prob',
#  'year',
#  'purch_prob_user',
#  'sum_watch',
#  'mean_watch',
#  'genre_features_user',
#  'genre_features']

# %%
from pyspark.ml.feature import VectorAssembler

vecAssembler = VectorAssembler(outputCol="features") # , handleInvalid="keep"
vecAssembler.setInputCols(['purch_prob',
 'year',
 'purch_prob_user',
 'sum_watch',
 'mean_watch',
 'genre_features_user',
 'genre_features'])
# Out:
# VectorAssembler_e72441155914

# %%
train_with_features = train_with_features.withColumn('id', f.col('item_id') + f.col('user_id')).fillna(0)
test_with_features = test_with_features.withColumn('id', f.col('item_id') + f.col('user_id')).fillna(0)

train_df = vecAssembler.transform(train_with_features).select('features', f.col('purchase').cast(ByteType()).alias('purchase'), 'id', 'item_id', 'user_id')
test_df = vecAssembler.transform(test_with_features).select('features', 'purchase', 'id', 'item_id', 'user_id')

# %%
test_df = test_df.cache()
train_df = train_df.cache()

# %%
start = time()
test_df.count()
print_worktime(time()-start)
# Out:
# Код отработал за 0 часов 1 минут 40.78083086013794 секунд

# %%
start = time()
train_df.count()
print_worktime(time()-start)
# Out:
# Код отработал за 0 часов 3 минут 38.504204988479614 секунд

# %%
gbt = GBTClassifier(featuresCol='features', labelCol="purchase", stepSize=0.01, maxIter=100, maxDepth=3)

# %%
start = time()
gbt_model = gbt.fit(train_df)
predictions_gbt = gbt_model.transform(test_df)
print_worktime(time()-start)

# %%
gbt_model.featureImportances

# %%
# paramGrid = ParamGridBuilder().addGrid(gbt.maxBins, [30, 50])\
#                               .addGrid(gbt.maxDepth, [3, 5])\
#                               .addGrid(gbt.stepSize, [0.1, 0.2])\
#                               .build()
# crossval = CrossValidator(estimator=gbt, estimatorParamMaps=paramGrid,
#                               evaluator=evaluator, numFolds=3, parallelism=5)

# %%
# start = time()
# cv_model = crossval.fit(train_df)
# print(cv_model.avgMetrics)
# print_worktime(time()-start)

# %%
# cv_model.bestModel

# %%
# cv_model.bestModel.extractParamMap()

# %%
# train_df = train_df.repartition(100)
# test_df = test_df.repartition(100)

# %%
predict_to_double = f.udf(lambda p: float(p[1]), DoubleType())

# %%
result_df = predictions_gbt.select('user_id', 'item_id', predict_to_double('prediction').alias('purchase'))

# %% [markdown]
# # Подход 2: ALS - быстро и качественнее

# %%
from pyspark.ml.recommendation import ALS

# %%
als = ALS(maxIter=20, regParam=2.1, rank=6, coldStartStrategy="nan", \
          userCol='user_id', itemCol='item_id', ratingCol='purchase', \
          nonnegative=False, implicitPrefs=True, alpha=5.0, seed=42)

# %%
train_als = train.select(f.col('user_id').cast(IntegerType()), f.col('item_id').cast(IntegerType()), f.col('purchase').cast(IntegerType()))
test_als = test.select(f.col('user_id').cast(IntegerType()), f.col('item_id').cast(IntegerType()), f.col('purchase').cast(IntegerType()))

# %%
test_als.show()

# %%
start = time()
als_model = als.fit(train_als)
print_worktime(time()-start)

# %%
start = time()
prediction_als = als_model.transform(test_als)
print_worktime(time()-start)

# %%
result = prediction_als.select('user_id', 'item_id', f.col('prediction').alias('purchase'))

# %%
start = time()
result = result.orderBy("user_id", "item_id")
result = result.toPandas()
print_worktime(time()-start)

# %%
result.to_csv('lab03.csv')

# %%
predictions_gbt_final.count()

# %%
predictions_gbt.show(2, truncate=False)

# %%
predictions_gbt.columns

# %%
result = prediction_als.select('user_id', 'item_id', f.col('prediction').alias('purchase'))
# result = result.withColumnRenamed('probability', 'prediction')

# %%
prediction_als.show()

# %%
# result.show(2, truncate=False)

# %%
start = time()
result = result.orderBy("user_id", "item_id")
result = result.toPandas()
print_worktime(time()-start)

# %%
result_df.shape

# %%
result.to_csv('lab03.csv')

# %%
spark.stop()
